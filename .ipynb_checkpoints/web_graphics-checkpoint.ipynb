# %%
import pandas as pd
import numpy as np
import plotly

# %%
import plotly.plotly as py

# %%
py.sign_in("NipunBatra", "lbgt6ksf1k")

# %%
# (1) Two lists of numbers
x1 = [1,2,3,5,6]
y1 = [1,4.5,7,24,38]

# (2) Make dictionary linking x and y coordinate lists to 'x' and 'y' keys
#     (mandatory in plotly v.1.0.8 and up)
trace1 = dict(x=x1, y=y1)

# (3) Make list of 1 trace, to be sent to Plotly
#     (mandatory in 1.0.8 and up)
data = [trace1]

# %%
py.iplot(data, filename='s0_first_plot')

# %%
from mpld3 import enable_notebook, disable_notebook

# %%
# %matplotlib inline

# %%
disable_notebook()

# %%
df = pd.DataFrame(np.random.randn(100,2))

# %%
df
# Out:
#            0         1
# 0   0.707909  0.711855
# 1  -0.484021  0.177317
# 2  -1.609252 -0.590485
# 3   1.292292 -0.945080
# 4   0.817511 -0.409380
# 5   0.289217 -0.488696
# 6   0.166223 -0.901144
# 7   0.297542  1.564154
# 8  -1.538612 -0.786292
# 9  -1.073622  2.024653
# 10 -1.656636  0.800258
# 11  0.578417 -0.208033
# 12 -0.791321  2.098338
# 13 -0.660824  0.498242
# 14 -0.038953  1.739478
# 15 -0.571270 -0.071027
# 16  0.147860 -1.093780
# 17  1.627736 -0.567223
# 18  1.742591 -1.260131
# 19  0.383642 -1.204922
# 20 -0.880323 -1.047216
# 21 -1.489805 -0.464989
# 22 -0.255540  1.334114
# 23 -0.646125  2.153387
# 24 -2.518064  1.773069
# 25 -1.396727 -0.856754
# 26  0.048347 -1.480838
# 27  0.167614 -1.930706
# 28 -0.262015  1.718379
# 29  1.440145 -0.373769
# ..       ...       ...
# 70 -0.532773  0.175598
# 71 -0.982239 -0.952731
# 72  0.788596 -1.537325
# 73  0.283444  0.636298
# 74  0.786783  0.327461
# 75  0.705355 -0.496471
# 76  1.478846  1.120487
# 77 -0.083258 -0.949442
# 78 -0.480541 -0.036322
# 79  0.725878  1.363429
# 80  0.727499  0.528379
# 81  1.468298  0.663849
# 82 -0.768460 -1.379105
# 83  0.177945 -0.437310
# 84 -0.071554 -0.302598
# 85  0.292691  0.422256
# 86  0.780565 -1.378577
# 87  0.371874  1.059319
# 88  1.339670 -0.339070
# 89  0.138366 -1.725166
# 90  0.571121  0.141608
# 91 -0.491035  0.633333
# 92  0.762947  1.993060
# 93 -0.075444  0.683299
# 94  1.170090 -0.886457
# 95 -0.179703 -0.371938
# 96  1.616649 -0.742370
# 97 -0.404853  0.168827
# 98  0.469632 -0.695081
# 99 -1.552770 -1.079229
#
# [100 rows x 2 columns]

# %%
df.plot()

# %%
enable_notebook()

# %%
df.plot()
